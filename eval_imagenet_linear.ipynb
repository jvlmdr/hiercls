# %%
import collections
import itertools
import json
import pathlib

import matplotlib
from matplotlib import pyplot as plt
from matplotlib import ticker
import ml_collections
import numpy as np
import pandas as pd
import torch

import hier
import hier_torch
import infer
import main
import metrics
import progmet
import tree_util

# %%
Experiment = collections.namedtuple('Experiment', ['config_file', 'model_file'])

def standard_experiment(experiment_dir, epoch):
    return Experiment(
        config_file=pathlib.Path(experiment_dir) / 'config.json',
        model_file=pathlib.Path(experiment_dir) / f'checkpoints/epoch-{epoch:04d}.pth',
    )

# %%
# Comparison losses: "2023-01-31-imagenet-linear"
EXP_ROOT = pathlib.Path('/mnt/ssd1/projects/2022-01-hierarchical/experiments/2023-01-31-imagenet-linear')
PLOT_DIR = 'output/plots/imagenet-linear-vitb32'
WEIGHT_DECAY = '0.000001'
experiments = {
    k: standard_experiment(
        experiment_dir=EXP_ROOT / f'vitb32-{k:s}-lr0.1-wd{WEIGHT_DECAY:s}-ep20',
        epoch=20)
    for k in [
        'flat_softmax',
        'multilabel_focal-1-0.9',
        'hier_softmax',
        'cond_multilabel',
        'share_random_cut-0',
        'share_flat_softmax',
        # 'descendant_softmax',
        'descendant_softmax_complement',
        'soft_margin-incorrect-5',
    ]
}
experiment_titles = {
    'flat_softmax': 'Flat softmax',
    'multilabel_focal-1-0.9': 'Multilabel focal',
    'hier_softmax': 'Cond softmax',
    'cond_multilabel': 'Cond sigmoid',
    'share_random_cut-0': 'Deep RTC',
    'share_flat_softmax': 'PS softmax',
    'descendant_softmax': 'Soft-max-descendant (all)',
    'descendant_softmax_complement': 'Soft-max-descendant',
    'soft_margin-incorrect-5': 'Soft-max-margin',
}

# # Compare hyperparams: "2023-01-31-imagenet-linear"
# PLOT_DIR = 'output/plots/imagenet-linear-vitb32-flat-sweep'
# experiments = {
#     f'lr{lr}-wd{wd}-ep{ep}': standard_experiment(
#         experiment_dir=(
#             '/mnt/ssd1/projects/2022-01-hierarchical/experiments/2023-01-31-imagenet-linear/'
#             f'vitb32-flat_softmax-lr{lr}-wd{wd}-ep{ep}/'),
#         epoch=int(ep))
#     for lr, wd, ep in itertools.product(['0.1', '0.01', '0.001'], ['0.0001', '0.00001', '0.000001'], ['20'])
# }
# experiment_titles = {k: k for k in experiments}

# EXP_ROOT = pathlib.Path('/mnt/ssd1/projects/2022-01-hierarchical/experiments/2022-04-25-imagenet-features')
# PLOT_DIR = 'output/plots/imagenet-linear-vitb32'
# experiments = {
#     'flat_softmax': standard_experiment(
#         experiment_dir=EXP_ROOT / 'vitb32-linear-flat_softmax-lr0.1-wd0.00001-ep20',
#         epoch=20),
#     'hier_softmax': standard_experiment(
#         experiment_dir=EXP_ROOT / 'vitb32-linear-hier_softmax-lr0.1-wd0.00001-ep20',
#         epoch=20),
#     'share_random_cut': standard_experiment(
#         experiment_dir=EXP_ROOT / 'vitb32-linear-share_random_cut-0-lr0.1-wd0.00001-ep20',
#         epoch=20),
#     'share_flat_softmax': standard_experiment(
#         experiment_dir=EXP_ROOT / 'vitb32-linear-share_flat_softmax-lr0.1-wd0.00001-ep20',
#         epoch=20),
#     'soft_margin-incorrect-5': standard_experiment(
#         experiment_dir=EXP_ROOT / 'vitb32-linear-soft_margin-incorrect-5-lr0.1-wd0.00001-ep20',
#         epoch=20),
# #     'soft_margin-incorrect-1': standard_experiment(
# #         experiment_dir=EXP_ROOT / 'vitb32-linear-soft_margin-incorrect-1-lr0.1-wd0.00001-ep20',
# #         epoch=20),
# #     'hard_margin-incorrect-1': standard_experiment(
# #         experiment_dir=EXP_ROOT / 'vitb32-linear-hard_margin-incorrect-1-lr0.1-wd0.00001-ep20',
# #         epoch=20),
# }
# experiment_titles = {
#     'flat_softmax': 'Flat softmax',
#     'hier_softmax': 'Cond softmax',
#     'share_random_cut': 'Deep RTC',
#     'share_flat_softmax': 'PS softmax',
#     'soft_margin-incorrect-5': 'Soft-max-margin',
#     # 'soft_margin-incorrect-1': 'Soft-max-margin (α = 1)',
#     # 'hard_margin-incorrect-1': 'Max-margin (α = 1)',
# }

# # Param sweep experiment: "2022-04-25-imagenet-features"
# experiments = {
#     f'flat-lr{lr}-wd{wd}-ep{ep}': standard_experiment(
#         experiment_dir=f'/mnt/ssd1/projects/2022-01-hierarchical/experiments/2022-04-25-imagenet-features/vitb32-linear-flat_softmax-lr{lr}-wd{wd}-ep{ep}/',
#         epoch=int(ep))
#     for lr, wd, ep in itertools.product(['0.1', '0.01', '0.001'], ['0.0001', '0.00001'], ['20', '100'])
# }

# %%
{name: pathlib.Path(experiment.config_file).exists() for name, experiment in experiments.items()}
# Out:
# {'flat_softmax': True,
#  'multilabel_focal-1-0.9': True,
#  'hier_softmax': True,
#  'cond_multilabel': True,
#  'share_random_cut-0': True,
#  'share_flat_softmax': True,
#  'descendant_softmax_complement': True,
#  'soft_margin-incorrect-5': True}

# %%
device = torch.device('cuda')

# %%
import configs.imagenet_linear

base_config = configs.imagenet_linear.get_config()
base_config.dataset_root = './resources/features/imagenet_vitb32/'

_, eval_dataset, tree, _, _, eval_label_map = main.make_datasets(base_config)

# %%
eval_loader = torch.utils.data.DataLoader(
    dataset=eval_dataset,
    batch_size=256,
    shuffle=False,
    num_workers=8)

# %%
is_leaf = tree.leaf_mask()
specificity = -tree.num_leaf_descendants()
not_trivial = (tree.num_children() != 1)

# %%
infer_fns = {
    'leaf': lambda p: infer.argmax_where(p, is_leaf),
    'majority': lambda p: infer.argmax_with_confidence(specificity, p, 0.5, not_trivial),
}

markers = {
    'leaf': 'o',
    'majority': '^',
}

# %%
colormap = matplotlib.cm.get_cmap('Set1')

# colors = dict(zip(experiments, map(colormap, itertools.count())))

color_index = {
    'flat_softmax': 0,
    'multilabel_focal-1-0.9': 1,
    'hier_softmax': 2,
    'cond_multilabel': 3,
    'share_random_cut-0': 4,
    'share_flat_softmax': 5,
    'descendant_softmax': 6,
    'descendant_softmax_complement': 8,
    'soft_margin-incorrect-5': 7,
}
colors = {k: colormap(v) for k, v in color_index.items()}

# %%
info_metric = metrics.UniformLeafInfoMetric(tree)
depth_metric = metrics.DepthMetric(tree)

metric_fns = {
    'exact': lambda gt, pr: pr == gt,
    'correct': metrics.IsCorrect(tree),
    'info_excess': info_metric.excess,
    'info_deficient': info_metric.deficient,
    'info_dist': info_metric.dist,
    'info_recall': info_metric.recall,
    'info_precision': info_metric.precision,
    'depth_excess': depth_metric.excess,
    'depth_deficient': depth_metric.deficient,
    'depth_dist': depth_metric.dist,
    'depth_recall': depth_metric.recall,
    'depth_precision': depth_metric.precision,
}

metric_titles = {
    'exact': 'Exact',
    'correct': 'Correct',
    'info_recall': 'Information Recall',
    'info_precision': 'Information Precision',
    'depth_recall': 'Depth Recall',
    'depth_precision': 'Depth Precision',
    'info_lca': 'LCA Information',
    'depth_lca': 'LCA Depth',
}

# %%
def apply_model(net, pred_fn, min_threshold, limit=None):
    # Per-example predictions.

    outputs = {
        'gt': [],  # Node in hierarchy.
        'pred': {method: [] for method in infer_fns},
    }
    # Sequence-per-example predictions. Cannot be concatenated due to ragged shape.
    seq_outputs = {
        'pred': [],
        'prob': [],
    }

    net.eval()
    with torch.inference_mode():
        meter = progmet.ProgressMeter('apply', interval_time=5)
        for minibatch in itertools.islice(meter(eval_loader), None):
            inputs, gt_labels = minibatch
            theta = net(inputs.to(device))
            prob = pred_fn(theta).cpu().numpy()
            pred = {}
            for name, infer_fn in infer_fns.items():
                pred[name] = infer_fn(prob)
            gt_node = eval_label_map.to_node[gt_labels]
            pred_seqs = [
                infer.pareto_optimal_predictions(specificity, p, min_threshold, not_trivial)
                for p in prob
            ]
            prob_seqs = [prob[i, pred_i] for i, pred_i in enumerate(pred_seqs)]
            # Caution: Predictions are *not* truncated.

            outputs['gt'].append(gt_node)
            for method in infer_fns:
                outputs['pred'][method].append(pred[method])
            seq_outputs['pred'].extend(pred_seqs)
            seq_outputs['prob'].extend(prob_seqs)

    # Concatenate results from minibatches.
    leaf_predicate = lambda x: not isinstance(x, dict)  # Treat lists as values, not containers.
    outputs = tree_util.tree_map(np.concatenate, outputs, is_leaf=leaf_predicate)

    return outputs, seq_outputs

# %%
def assess_predictions(outputs, seq_outputs):
    gt = outputs['gt']
    pred = outputs['pred']
    pred_seq = seq_outputs['pred']
    prob_seq = seq_outputs['prob']

    # Evaluate predictions for each method.
    pred = {
        method: hier.truncate_at_lca(tree, gt, pr)
        for method, pr in pred.items()
    }
    pred_metrics = {
        method: {field: np.mean(metric_fn(gt, pr))
                 for field, metric_fn in metric_fns.items()}
        for method, pr in pred.items()
    }

    # Evaluate predictions in Pareto sequence.
    find_lca = hier.FindLCA(tree)
    specificity_seq = [specificity[pr_i] for pr_i in pred_seq]
    pred_seq = [hier.truncate_given_lca(gt_i, pr_i, find_lca(gt_i, pr_i)) for gt_i, pr_i in zip(gt, pred_seq)]
    metric_values_seq = {
        field: [metric_fn(gt_i, pr_i) for gt_i, pr_i in zip(gt, pred_seq)]
        for field, metric_fn in metric_fns.items()
    }
    pareto_scores, pareto_totals = metrics.operating_curve(prob_seq, metric_values_seq)
    pareto_means = {k: v / len(gt) for k, v in pareto_totals.items()}

    return pred_metrics, pareto_scores, pareto_means

# %%
# Initialize results if not defined.
try:
    results
except NameError:
    results = {}  # Not defined.

# %%
MIN_THRESHOLD = None  # Values less than 0.5 may increase runtime significantly.

for name, (config_file, model_file) in experiments.items():
    if name in results:
        print('cached:', name)
        continue

    # Load model.
    with open(config_file, 'r') as f:
        config = ml_collections.ConfigDict(json.load(f))
    num_outputs = main.get_num_outputs(config.predict, tree)
    net = main.make_model(config.model, num_outputs)
    missing_keys, unexpected_keys = net.load_state_dict(torch.load(model_file), strict=True)
    assert not missing_keys
    assert not unexpected_keys

    net.to(device)
    _, pred_fn = main.make_loss(config, tree, device)
    outputs, seq_outputs = apply_model(net, pred_fn, min_threshold=MIN_THRESHOLD)
    pred_metrics, pareto_scores, pareto_metrics = assess_predictions(outputs, seq_outputs)
    results[name] = {
        'pred_metrics': pred_metrics,
        'pareto_scores': pareto_scores,
        'pareto_metrics': pareto_metrics,
    }
# Out:
# cached: flat_softmax
# cached: multilabel_focal-1-0.9
# cached: hier_softmax
# cached: cond_multilabel
# cached: share_random_cut-0
# cached: share_flat_softmax
# cached: descendant_softmax_complement
# cached: soft_margin-incorrect-5

# %%
INTEGRALS = {
    'AC(depth)': ('depth_recall', 'correct'),
    'AC(info)': ('info_recall', 'correct'),
    'AP(depth)': ('depth_recall', 'depth_precision'),
    'AP(info)': ('info_recall', 'info_precision'),
    'AC(exact)': ('exact', 'correct'),
}

auc = {
    integral_key: {
        name: metrics.pareto_integrate(
            results[name]['pareto_metrics'][x],
            results[name]['pareto_metrics'][y])
        for name in experiments if name in results
    } for integral_key, (x, y) in INTEGRALS.items()
}

auc = pd.DataFrame(auc)
auc = auc.set_index(auc.index.map(experiment_titles))
auc.style.format('{:.1%}'.format)
# Out:
# <style type="text/css">
# </style>
# <table id="T_def35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_def35_level0_col0" class="col_heading level0 col0" >AC(depth)</th>
#       <th id="T_def35_level0_col1" class="col_heading level0 col1" >AC(info)</th>
#       <th id="T_def35_level0_col2" class="col_heading level0 col2" >AP(depth)</th>
#       <th id="T_def35_level0_col3" class="col_heading level0 col3" >AP(info)</th>
#       <th id="T_def35_level0_col4" class="col_heading level0 col4" >AC(exact)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_def35_level0_row0" class="row_heading level0 row0" >Flat softmax</th>
#       <td id="T_def35_row0_col0" class="data row0 col0" >89.7%</td>
#       <td id="T_def35_row0_col1" class="data row0 col1" >82.3%</td>
#       <td id="T_def35_row0_col2" class="data row0 col2" >90.7%</td>
#       <td id="T_def35_row0_col3" class="data row0 col3" >83.4%</td>
#       <td id="T_def35_row0_col4" class="data row0 col4" >71.6%</td>
#     </tr>
#     <tr>
#       <th id="T_def35_level0_row1" class="row_heading level0 row1" >Multilabel focal</th>
#       <td id="T_def35_row1_col0" class="data row1 col0" >87.3%</td>
#       <td id="T_def35_row1_col1" class="data row1 col1" >78.5%</td>
#       <td id="T_def35_row1_col2" class="data row1 col2" >89.4%</td>
#       <td id="T_def35_row1_col3" class="data row1 col3" >80.6%</td>
#       <td id="T_def35_row1_col4" class="data row1 col4" >65.9%</td>
#     </tr>
#     <tr>
#       <th id="T_def35_level0_row2" class="row_heading level0 row2" >Cond softmax</th>
#       <td id="T_def35_row2_col0" class="data row2 col0" >83.1%</td>
#       <td id="T_def35_row2_col1" class="data row2 col1" >71.4%</td>
#       <td id="T_def35_row2_col2" class="data row2 col2" >85.5%</td>
#       <td id="T_def35_row2_col3" class="data row2 col3" >73.9%</td>
#       <td id="T_def35_row2_col4" class="data row2 col4" >58.1%</td>
#     </tr>
#     <tr>
#       <th id="T_def35_level0_row3" class="row_heading level0 row3" >Cond sigmoid</th>
#       <td id="T_def35_row3_col0" class="data row3 col0" >83.2%</td>
#       <td id="T_def35_row3_col1" class="data row3 col1" >71.7%</td>
#       <td id="T_def35_row3_col2" class="data row3 col2" >85.9%</td>
#       <td id="T_def35_row3_col3" class="data row3 col3" >74.5%</td>
#       <td id="T_def35_row3_col4" class="data row3 col4" >58.3%</td>
#     </tr>
#     <tr>
#       <th id="T_def35_level0_row4" class="row_heading level0 row4" >Deep RTC</th>
#       <td id="T_def35_row4_col0" class="data row4 col0" >84.3%</td>
#       <td id="T_def35_row4_col1" class="data row4 col1" >78.8%</td>
#       <td id="T_def35_row4_col2" class="data row4 col2" >89.3%</td>
#       <td id="T_def35_row4_col3" class="data row4 col3" >81.6%</td>
#       <td id="T_def35_row4_col4" class="data row4 col4" >70.4%</td>
#     </tr>
#     <tr>
#       <th id="T_def35_level0_row5" class="row_heading level0 row5" >PS softmax</th>
#       <td id="T_def35_row5_col0" class="data row5 col0" >89.7%</td>
#       <td id="T_def35_row5_col1" class="data row5 col1" >82.3%</td>
#       <td id="T_def35_row5_col2" class="data row5 col2" >90.6%</td>
#       <td id="T_def35_row5_col3" class="data row5 col3" >83.3%</td>
#       <td id="T_def35_row5_col4" class="data row5 col4" >71.5%</td>
#     </tr>
#     <tr>
#       <th id="T_def35_level0_row6" class="row_heading level0 row6" >Soft-max-descendant</th>
#       <td id="T_def35_row6_col0" class="data row6 col0" >89.2%</td>
#       <td id="T_def35_row6_col1" class="data row6 col1" >81.7%</td>
#       <td id="T_def35_row6_col2" class="data row6 col2" >90.5%</td>
#       <td id="T_def35_row6_col3" class="data row6 col3" >82.8%</td>
#       <td id="T_def35_row6_col4" class="data row6 col4" >68.5%</td>
#     </tr>
#     <tr>
#       <th id="T_def35_level0_row7" class="row_heading level0 row7" >Soft-max-margin</th>
#       <td id="T_def35_row7_col0" class="data row7 col0" >89.6%</td>
#       <td id="T_def35_row7_col1" class="data row7 col1" >82.4%</td>
#       <td id="T_def35_row7_col2" class="data row7 col2" >90.6%</td>
#       <td id="T_def35_row7_col3" class="data row7 col3" >83.4%</td>
#       <td id="T_def35_row7_col4" class="data row7 col4" >72.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
INTERCEPTS = [
    'depth_recall',
    'info_recall',
    'exact',
]

CORRECT = [95, 90]

recalls = {
    (c, y): {
        name: metrics.pareto_intercept(
            results[name]['pareto_metrics']['correct'],
            results[name]['pareto_metrics'][y],
            c / 100)
        for name in results
    } for c in CORRECT for y in INTERCEPTS
}

recalls = pd.DataFrame(recalls)
recalls = recalls.set_index(recalls.index.map(experiment_titles)).sort_index()
recalls.style.format('{:.1%}'.format)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c60e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c60e_level0_col0" class="col_heading level0 col0" colspan="3">95</th>
#       <th id="T_5c60e_level0_col3" class="col_heading level0 col3" colspan="3">90</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_5c60e_level1_col0" class="col_heading level1 col0" >depth_recall</th>
#       <th id="T_5c60e_level1_col1" class="col_heading level1 col1" >info_recall</th>
#       <th id="T_5c60e_level1_col2" class="col_heading level1 col2" >exact</th>
#       <th id="T_5c60e_level1_col3" class="col_heading level1 col3" >depth_recall</th>
#       <th id="T_5c60e_level1_col4" class="col_heading level1 col4" >info_recall</th>
#       <th id="T_5c60e_level1_col5" class="col_heading level1 col5" >exact</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c60e_level0_row0" class="row_heading level0 row0" >Cond sigmoid</th>
#       <td id="T_5c60e_row0_col0" class="data row0 col0" >64.2%</td>
#       <td id="T_5c60e_row0_col1" class="data row0 col1" >40.7%</td>
#       <td id="T_5c60e_row0_col2" class="data row0 col2" >17.5%</td>
#       <td id="T_5c60e_row0_col3" class="data row0 col3" >71.1%</td>
#       <td id="T_5c60e_row0_col4" class="data row0 col4" >50.7%</td>
#       <td id="T_5c60e_row0_col5" class="data row0 col5" >28.6%</td>
#     </tr>
#     <tr>
#       <th id="T_5c60e_level0_row1" class="row_heading level0 row1" >Cond softmax</th>
#       <td id="T_5c60e_row1_col0" class="data row1 col0" >66.1%</td>
#       <td id="T_5c60e_row1_col1" class="data row1 col1" >43.9%</td>
#       <td id="T_5c60e_row1_col2" class="data row1 col2" >21.9%</td>
#       <td id="T_5c60e_row1_col3" class="data row1 col3" >73.0%</td>
#       <td id="T_5c60e_row1_col4" class="data row1 col4" >54.3%</td>
#       <td id="T_5c60e_row1_col5" class="data row1 col5" >33.8%</td>
#     </tr>
#     <tr>
#       <th id="T_5c60e_level0_row2" class="row_heading level0 row2" >Deep RTC</th>
#       <td id="T_5c60e_row2_col0" class="data row2 col0" >41.7%</td>
#       <td id="T_5c60e_row2_col1" class="data row2 col1" >40.5%</td>
#       <td id="T_5c60e_row2_col2" class="data row2 col2" >37.9%</td>
#       <td id="T_5c60e_row2_col3" class="data row2 col3" >62.3%</td>
#       <td id="T_5c60e_row2_col4" class="data row2 col4" >59.7%</td>
#       <td id="T_5c60e_row2_col5" class="data row2 col5" >54.9%</td>
#     </tr>
#     <tr>
#       <th id="T_5c60e_level0_row3" class="row_heading level0 row3" >Flat softmax</th>
#       <td id="T_5c60e_row3_col0" class="data row3 col0" >81.5%</td>
#       <td id="T_5c60e_row3_col1" class="data row3 col1" >68.2%</td>
#       <td id="T_5c60e_row3_col2" class="data row3 col2" >49.6%</td>
#       <td id="T_5c60e_row3_col3" class="data row3 col3" >86.3%</td>
#       <td id="T_5c60e_row3_col4" class="data row3 col4" >75.9%</td>
#       <td id="T_5c60e_row3_col5" class="data row3 col5" >60.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5c60e_level0_row4" class="row_heading level0 row4" >Multilabel focal</th>
#       <td id="T_5c60e_row4_col0" class="data row4 col0" >69.1%</td>
#       <td id="T_5c60e_row4_col1" class="data row4 col1" >47.9%</td>
#       <td id="T_5c60e_row4_col2" class="data row4 col2" >22.3%</td>
#       <td id="T_5c60e_row4_col3" class="data row4 col3" >77.7%</td>
#       <td id="T_5c60e_row4_col4" class="data row4 col4" >60.6%</td>
#       <td id="T_5c60e_row4_col5" class="data row4 col5" >35.3%</td>
#     </tr>
#     <tr>
#       <th id="T_5c60e_level0_row5" class="row_heading level0 row5" >PS softmax</th>
#       <td id="T_5c60e_row5_col0" class="data row5 col0" >81.6%</td>
#       <td id="T_5c60e_row5_col1" class="data row5 col1" >68.4%</td>
#       <td id="T_5c60e_row5_col2" class="data row5 col2" >49.5%</td>
#       <td id="T_5c60e_row5_col3" class="data row5 col3" >86.3%</td>
#       <td id="T_5c60e_row5_col4" class="data row5 col4" >76.1%</td>
#       <td id="T_5c60e_row5_col5" class="data row5 col5" >60.6%</td>
#     </tr>
#     <tr>
#       <th id="T_5c60e_level0_row6" class="row_heading level0 row6" >Soft-max-descendant</th>
#       <td id="T_5c60e_row6_col0" class="data row6 col0" >77.9%</td>
#       <td id="T_5c60e_row6_col1" class="data row6 col1" >64.1%</td>
#       <td id="T_5c60e_row6_col2" class="data row6 col2" >28.9%</td>
#       <td id="T_5c60e_row6_col3" class="data row6 col3" >84.2%</td>
#       <td id="T_5c60e_row6_col4" class="data row6 col4" >73.2%</td>
#       <td id="T_5c60e_row6_col5" class="data row6 col5" >44.8%</td>
#     </tr>
#     <tr>
#       <th id="T_5c60e_level0_row7" class="row_heading level0 row7" >Soft-max-descendant (all)</th>
#       <td id="T_5c60e_row7_col0" class="data row7 col0" >77.8%</td>
#       <td id="T_5c60e_row7_col1" class="data row7 col1" >63.6%</td>
#       <td id="T_5c60e_row7_col2" class="data row7 col2" >24.6%</td>
#       <td id="T_5c60e_row7_col3" class="data row7 col3" >83.8%</td>
#       <td id="T_5c60e_row7_col4" class="data row7 col4" >72.5%</td>
#       <td id="T_5c60e_row7_col5" class="data row7 col5" >42.2%</td>
#     </tr>
#     <tr>
#       <th id="T_5c60e_level0_row8" class="row_heading level0 row8" >Soft-max-margin</th>
#       <td id="T_5c60e_row8_col0" class="data row8 col0" >81.3%</td>
#       <td id="T_5c60e_row8_col1" class="data row8 col1" >69.0%</td>
#       <td id="T_5c60e_row8_col2" class="data row8 col2" >53.9%</td>
#       <td id="T_5c60e_row8_col3" class="data row8 col3" >86.3%</td>
#       <td id="T_5c60e_row8_col4" class="data row8 col4" >76.7%</td>
#       <td id="T_5c60e_row8_col5" class="data row8 col5" >63.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
def plot_metrics(x, y, tickres=None, is_pr=True, xmin=None, legend=True, save=False):
    plt.figure(figsize=(5, 4))
    for name in experiments:
        if name not in results:
            continue
        pred_metrics = results[name]['pred_metrics']
        pareto_scores = results[name]['pareto_scores']
        pareto_metrics = results[name]['pareto_metrics']
        ge = np.concatenate(([True], pareto_scores >= 0.5))
        le = np.concatenate(([False], pareto_scores <= 0.5))
        plt.plot(pareto_metrics[x][ge], pareto_metrics[y][ge],
                 color=colors[name], label=experiment_titles.get(name, name))
        plt.plot(pareto_metrics[x][le], pareto_metrics[y][le],
                 color=colors[name], linestyle='--')
        for method in ['leaf', 'majority']:  # pred_metrics.items():
            plt.plot(pred_metrics[method][x], pred_metrics[method][y],
                     color=colors[name], marker=markers[method],
                     markerfacecolor='none')

    ax = plt.gca()
    if is_pr:
        plt.xlim(left=0)
        plt.ylim(top=1)
        # plt.ylim(np.clip(plt.ylim(), 0, 1))
        # plt.xlim(np.clip(plt.xlim(), 0, 1))
    if xmin is not None:
        plt.xlim(left=xmin)
    if tickres:
        ax.xaxis.set_major_locator(ticker.MultipleLocator(tickres))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(tickres))
    # plt.axis('equal')
    # plt.gca().set_aspect(1)
    plt.grid()
    plt.xlabel(metric_titles.get(x, x))
    plt.ylabel(metric_titles.get(y, y))
    if legend:
        plt.legend()

    if save:
        pathlib.Path(PLOT_DIR).mkdir(parents=True, exist_ok=True)
        plt.savefig(pathlib.Path(PLOT_DIR) / f'{x}-{y}.pdf')

# %%
plot_metrics('exact', 'correct', tickres=0.1, legend=False, save=True)

# %%
plot_metrics('info_recall', 'correct', tickres=0.1, xmin=0.3, legend=False, save=True)

# %%
plot_metrics('info_recall', 'info_precision', tickres=0.1, xmin=0.3, legend=False, save=True)

# %%
plot_metrics('depth_recall', 'correct', tickres=0.1, xmin=0.3, legend=False, save=True)

# %%
plot_metrics('depth_recall', 'depth_precision', tickres=0.1, legend=False, xmin=0.3, save=True)
